# %%
# %matplotlib notebook
from numpy import *
from matplotlib.pyplot import *

# %%
import subprocess
import shlex
import os

# %% [markdown]
# <hr style="border-width:4px; border-color:coral"></hr>
#
# ## Run Smoke3d
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# This notebook has two parts.
#
# * **Part 1:** Create artificial to simulate "observations" at gauges at a final output time $T$.
#
#
# * **Part 2:** Estimate value of $S$ by solving a least squares problem.  This will be a linear or nonlinear  problem with dimension equal to the the number of gauges.  The function to be optimized involves a call to ForestClaw.
#
# As a first step, test that we can run ForestClaw from this notebook

# %% [markdown]
# ### Problem setup
#
# This code assumes that we will only observe solution at final time.

# %%
# This is the command that will get called from the command line

# Model parameters
source_model = 2

# Parameters to estimate
S_true = 20
alpha_true = 0.0001

# Number of parameters to estimate
nparms = 2

# Keep track of how many times we call ForestClaw
fclaw_counter = 0

# %% [markdown]
# ## ForestClaw wrapper
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We can wrap ForestClaw in a Python function.
#
# * Reads data from `fclaw_options.ini`, spatial and temporal resolution
#
# * A ForestClaw run will read data from a gauge file (created below) and report on values at gauges at regular time intervals, specified in ForetClaw options file `fclaw_options.ini'
#
# * This wrapper takes two input parameters $S$ and $\alpha$ that control the source term.  The source term model is also used, but is set as a global variable above.
#
# * The output are gauge files, that are read in routines below.  The function $G(S,\alpha)$ will call this function and return the value of $q(x,t)$ at the final time, at each of the gauges.

# %%
def run_ForestClaw(S, alpha):
    # Parameters : 
    global fclaw_counter
    shell_cmd = './latlong --user:source-model={:d} --user:S0={:.16f} --user:alpha={:.16e}'.format
    cmd = shell_cmd(source_model, S, alpha)
    arg_list = shlex.split(cmd) 
    output = subprocess.run(arg_list, capture_output=True,text=True)
    
    fclaw_counter += 1
    return output.returncode, output

# %% [markdown]
# ### Test ForestClaw wrapper

# %%
# Test that we can call ForestClaw

errout,output = run_ForestClaw(S_true,alpha_true)

if errout != 0:
    print("latlong : Something bad happened!")
    print(output.stdout)
    exit(0)
else:
    print("Test successful!")        
    
# Reset counter
fclaw_counter = 0
    
print(output.stdout)
# Out:
# Test successful!
# [libsc] This is libsc 2.8.1.57-a813
# [libsc] CPP                      /opt/local/bin/mpicc -E
# [libsc] CPPFLAGS
# [libsc] CC                       /opt/local/bin/mpicc
# [libsc] CFLAGS
# [libsc] LDFLAGS                  -Wl,-syslibroot,/Library/Developer/CommandLineTools/SDKs/MacOSX12.sdk -Wl,-flat_namespace -Wl,-commons,use_dylibs -L/opt/local/lib
# [libsc] LIBS                     /opt/local/lib/libz.dylib;m
# [p4est] This is p4est 2.0.94-00da
# [p4est] CPP                      /opt/local/bin/mpicc -E
# [p4est] CPPFLAGS
# [p4est] CC                       /opt/local/bin/mpicc
# [p4est] CFLAGS                   -O2 -g -Wall -DP4EST_ENABLE_DEBUG=1 -DSC_ENABLE_DEBUG=1
# [p4est] LDFLAGS
# [p4est] LIBS                     ;/opt/local/lib/libz.dylib;m
# [fclaw] This is ForestClaw 0.1.4880-4dae
# [fclaw] CPP                      /opt/local/bin/mpicc -E
# [fclaw] CPPFLAGS
# [fclaw] F77
# [fclaw] FFLAGS                   -O2 -g -Wall -Wno-unused-dummy-argument
# [fclaw] CC                       /opt/local/bin/mpicc
# [fclaw] CFLAGS                   -O2 -g -Wall -DFCLAW_ENABLE_DEBUG=1
# [fclaw] CXX                      /opt/local/bin/mpicxx
# [fclaw] CXXFLAGS
# [fclaw] LDFLAGS                  -Wl,-syslibroot,/Library/Developer/CommandLineTools/SDKs/MacOSX12.sdk -Wl,-flat_namespace -Wl,-commons,use_dylibs -L/opt/local/lib
# [fclaw] FLIBS
# [fclaw] LIBS                     ;/opt/local/lib/libz.dylib;m
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Options:
# [fclaw]    help                                 false
# [fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw]    verbosity                            production
# [fclaw]    lib-verbosity                        essential
# [fclaw]    initial_dt                           0.01
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    reduce-cfl                           true
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               2
# [fclaw]    nout                                 10
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     false
# [fclaw]    outstyle-uses-maxlevel               false
# [fclaw]    subcycle                             true
# [fclaw]    weighted_partition                   true
# [fclaw]    time-sync                            false
# [fclaw]    flux-correction                      true
# [fclaw]    fluctuation-correction               true
# [fclaw]    output                               true
# [fclaw]    output-gauges                        false
# [fclaw]    gauge-buffer-length                  1
# [fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         8 6
# [fclaw]    tikz-plot-prefix                     plot
# [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-mesh-only                       false
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             0
# [fclaw]    maxlevel                             3
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         3
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.0001
# [fclaw]    coarsen_threshold                    1e-05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check                   false
# [fclaw]    report-timing                        true
# [fclaw]    report-timing-verbosity              wall
# [fclaw]    ghost_patch_pack_area                true
# [fclaw]    ghost_patch_pack_extra               false
# [fclaw]    ghost_patch_pack_numextrafields      0
# [fclaw]    trapfpe                              false
# [fclaw]    mpi_debug                            false
# [fclaw]    ax                                   0
# [fclaw]    bx                                   1
# [fclaw]    ay                                   0
# [fclaw]    by                                   1
# [fclaw]    az                                   0
# [fclaw]    bz                                   1
# [fclaw]    manifold                             true
# [fclaw]    mi                                   5
# [fclaw]    mj                                   6
# [fclaw]    periodic_x                           false
# [fclaw]    periodic_y                           false
# [fclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         32
# [fclaw]    clawpatch:my                         32
# [fclaw]    clawpatch:maux                       7
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:rhs-fields                 1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       false
# [fclaw]    clawpatch:save-aux                   false
# [fclaw]    clawpatch:refinement-criteria        value
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     1
# [fclaw]    clawpack46:src_term                  true
# [fclaw]    clawpack46:use-fwaves                true
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [fclaw]    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 true
# [fclaw]    clawpack46:vtk-out                   false
# [fclaw]    user:example                         1
# [fclaw]    user:initial-condition               0
# [fclaw]    user:source-model                    2
# [fclaw]    user:radius-fire                     1.5
# [fclaw]    user:radius-sphere                   1
# [fclaw]    user:S0                              20
# [fclaw]    user:alpha                           0.0001
# [fclaw]    user:latitude                        32 51
# [fclaw]    user:longitude                       -125 -105
# [fclaw]    user:center-fire                     -120 35.5
# [fclaw]    user:velocity                        0.2 0.2
# [fclaw]    user:claw-version                    4
# [fclaw] Arguments: none
# [p4est 0] Local minimum/maximum levels:  0  0
# [p4est] Global minimum/maximum levels:  0  0
# [p4est 0] Patches on level  0:        30
# [fclaw] Max threads set to 0
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Level 0 (0-0) step     1 : dt =    1.000e-02; maxcfl (step) =    1.618; Final time =       0.0100
# [fclaw]    WARNING : Maximum CFL exceeded; retaking time step
# [fclaw] Level 0 (0-0) step     1 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0056
# [fclaw] Level 0 (0-1) step     2 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0111
# [fclaw] Level 0 (0-2) step     3 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0167
# [fclaw] Level 0 (0-3) step     4 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0223
# [fclaw] Level 0 (0-3) step     5 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0278
# [fclaw] Level 0 (0-3) step     6 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0334
# [fclaw] Level 0 (0-3) step     7 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0389
# [fclaw] Level 0 (0-3) step     8 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0445
# [fclaw] Level 0 (0-3) step     9 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0501
# [fclaw] Level 0 (0-3) step    10 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0556
# [fclaw] Level 0 (0-3) step    11 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0612
# [fclaw] Level 0 (0-3) step    12 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0668
# [fclaw] Level 0 (0-3) step    13 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0723
# [fclaw] Level 0 (0-3) step    14 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0779
# [fclaw] Level 0 (0-3) step    15 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0834
# [fclaw] Level 0 (0-3) step    16 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0890
# [fclaw] Level 0 (0-3) step    17 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.0946
# [fclaw] Level 0 (0-3) step    18 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1001
# [fclaw] Level 0 (0-3) step    19 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1057
# [fclaw] Level 0 (0-3) step    20 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1113
# [fclaw] Level 0 (0-3) step    21 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1168
# [fclaw] Level 0 (0-3) step    22 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1224
# [fclaw] Level 0 (0-3) step    23 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1279
# [fclaw] Level 0 (0-3) step    24 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1335
# [fclaw] Level 0 (0-3) step    25 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1391
# [fclaw] Level 0 (0-3) step    26 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1446
# [fclaw] Level 0 (0-3) step    27 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1502
# [fclaw] Level 0 (0-3) step    28 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1558
# [fclaw] Level 0 (0-3) step    29 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1613
# [fclaw] Level 0 (0-3) step    30 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1669
# [fclaw] Level 0 (0-3) step    31 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1724
# [fclaw] Level 0 (0-3) step    32 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1780
# [fclaw] Level 0 (0-3) step    33 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1836
# [fclaw] Level 0 (0-3) step    34 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1891
# [fclaw] Level 0 (0-3) step    35 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.1947
# [fclaw] Level 0 (0-3) step    36 : dt =    5.310e-03; maxcfl (step) =    0.859; Final time =       0.2000
# [fclaw] Output Frame    1  at time   2.00000000e-01
#
# [fclaw] Level 0 (0-3) step    37 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2056
# [fclaw] Level 0 (0-3) step    38 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2111
# [fclaw] Level 0 (0-3) step    39 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2167
# [fclaw] Level 0 (0-3) step    40 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2223
# [fclaw] Level 0 (0-3) step    41 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2278
# [fclaw] Level 0 (0-3) step    42 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2334
# [fclaw] Level 0 (0-3) step    43 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2389
# [fclaw] Level 0 (0-3) step    44 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2445
# [fclaw] Level 0 (0-3) step    45 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2501
# [fclaw] Level 0 (0-3) step    46 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2556
# [fclaw] Level 0 (0-3) step    47 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2612
# [fclaw] Level 0 (0-3) step    48 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2668
# [fclaw] Level 0 (0-3) step    49 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2723
# [fclaw] Level 0 (0-3) step    50 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2779
# [fclaw] Level 0 (0-3) step    51 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2834
# [fclaw] Level 0 (0-3) step    52 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2890
# [fclaw] Level 0 (0-3) step    53 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.2946
# [fclaw] Level 0 (0-3) step    54 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3001
# [fclaw] Level 0 (0-3) step    55 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3057
# [fclaw] Level 0 (0-3) step    56 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3113
# [fclaw] Level 0 (0-3) step    57 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3168
# [fclaw] Level 0 (0-3) step    58 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3224
# [fclaw] Level 0 (0-3) step    59 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3279
# [fclaw] Level 0 (0-3) step    60 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3335
# [fclaw] Level 0 (0-3) step    61 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3391
# [fclaw] Level 0 (0-3) step    62 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3446
# [fclaw] Level 0 (0-3) step    63 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3502
# [fclaw] Level 0 (0-3) step    64 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3558
# [fclaw] Level 0 (0-3) step    65 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3613
# [fclaw] Level 0 (0-3) step    66 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3669
# [fclaw] Level 0 (0-3) step    67 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3724
# [fclaw] Level 0 (0-3) step    68 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3780
# [fclaw] Level 0 (0-3) step    69 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3836
# [fclaw] Level 0 (0-3) step    70 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3891
# [fclaw] Level 0 (0-3) step    71 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.3947
# [fclaw] Level 0 (0-3) step    72 : dt =    5.310e-03; maxcfl (step) =    0.859; Final time =       0.4000
# [fclaw] Output Frame    2  at time   4.00000000e-01
#
# [fclaw] Level 0 (0-3) step    73 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4056
# [fclaw] Level 0 (0-3) step    74 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4111
# [fclaw] Level 0 (0-3) step    75 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4167
# [fclaw] Level 0 (0-3) step    76 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4223
# [fclaw] Level 0 (0-3) step    77 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4278
# [fclaw] Level 0 (0-3) step    78 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4334
# [fclaw] Level 0 (0-3) step    79 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4389
# [fclaw] Level 0 (0-3) step    80 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4445
# [fclaw] Level 0 (0-3) step    81 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4501
# [fclaw] Level 0 (0-3) step    82 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4556
# [fclaw] Level 0 (0-3) step    83 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4612
# [fclaw] Level 0 (0-3) step    84 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4668
# [fclaw] Level 0 (0-3) step    85 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4723
# [fclaw] Level 0 (0-3) step    86 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4779
# [fclaw] Level 0 (0-3) step    87 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4834
# [fclaw] Level 0 (0-3) step    88 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4890
# [fclaw] Level 0 (0-3) step    89 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.4946
# [fclaw] Level 0 (0-3) step    90 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5001
# [fclaw] Level 0 (0-3) step    91 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5057
# [fclaw] Level 0 (0-3) step    92 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5113
# [fclaw] Level 0 (0-3) step    93 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5168
# [fclaw] Level 0 (0-3) step    94 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5224
# [fclaw] Level 0 (0-3) step    95 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5279
# [fclaw] Level 0 (0-3) step    96 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5335
# [fclaw] Level 0 (0-3) step    97 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5391
# [fclaw] Level 0 (0-3) step    98 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5446
# [fclaw] Level 0 (0-3) step    99 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5502
# [fclaw] Level 0 (0-3) step   100 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5558
# [fclaw] Level 0 (0-3) step   101 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5613
# [fclaw] Level 0 (0-3) step   102 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5669
# [fclaw] Level 0 (0-3) step   103 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5724
# [fclaw] Level 0 (0-3) step   104 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5780
# [fclaw] Level 0 (0-3) step   105 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5836
# [fclaw] Level 0 (0-3) step   106 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5891
# [fclaw] Level 0 (0-3) step   107 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.5947
# [fclaw] Level 0 (0-3) step   108 : dt =    5.310e-03; maxcfl (step) =    0.859; Final time =       0.6000
# [fclaw] Output Frame    3  at time   6.00000000e-01
#
# [fclaw] Level 0 (0-3) step   109 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6056
# [fclaw] Level 0 (0-3) step   110 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6111
# [fclaw] Level 0 (0-3) step   111 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6167
# [fclaw] Level 0 (0-3) step   112 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6223
# [fclaw] Level 0 (0-3) step   113 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6278
# [fclaw] Level 0 (0-3) step   114 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6334
# [fclaw] Level 0 (0-3) step   115 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6389
# [fclaw] Level 0 (0-3) step   116 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6445
# [fclaw] Level 0 (0-3) step   117 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6501
# [fclaw] Level 0 (0-3) step   118 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6556
# [fclaw] Level 0 (0-3) step   119 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6612
# [fclaw] Level 0 (0-3) step   120 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6668
# [fclaw] Level 0 (0-3) step   121 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6723
# [fclaw] Level 0 (0-3) step   122 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6779
# [fclaw] Level 0 (0-3) step   123 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6834
# [fclaw] Level 0 (0-3) step   124 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6890
# [fclaw] Level 0 (0-3) step   125 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.6946
# [fclaw] Level 0 (0-3) step   126 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7001
# [fclaw] Level 0 (0-3) step   127 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7057
# [fclaw] Level 0 (0-3) step   128 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7113
# [fclaw] Level 0 (0-3) step   129 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7168
# [fclaw] Level 0 (0-3) step   130 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7224
# [fclaw] Level 0 (0-3) step   131 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7279
# [fclaw] Level 0 (0-3) step   132 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7335
# [fclaw] Level 0 (0-3) step   133 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7391
# [fclaw] Level 0 (0-3) step   134 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7446
# [fclaw] Level 0 (0-3) step   135 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7502
# [fclaw] Level 0 (0-3) step   136 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7558
# [fclaw] Level 0 (0-3) step   137 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7613
# [fclaw] Level 0 (0-3) step   138 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7669
# [fclaw] Level 0 (0-3) step   139 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7724
# [fclaw] Level 0 (0-3) step   140 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7780
# [fclaw] Level 0 (0-3) step   141 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7836
# [fclaw] Level 0 (0-3) step   142 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7891
# [fclaw] Level 0 (0-3) step   143 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.7947
# [fclaw] Level 0 (0-3) step   144 : dt =    5.310e-03; maxcfl (step) =    0.859; Final time =       0.8000
# [fclaw] Output Frame    4  at time   8.00000000e-01
#
# [fclaw] Level 0 (0-3) step   145 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8056
# [fclaw] Level 0 (0-3) step   146 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8111
# [fclaw] Level 0 (0-3) step   147 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8167
# [fclaw] Level 0 (0-3) step   148 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8223
# [fclaw] Level 0 (0-3) step   149 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8278
# [fclaw] Level 0 (0-3) step   150 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8334
# [fclaw] Level 0 (0-3) step   151 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8389
# [fclaw] Level 0 (0-3) step   152 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8445
# [fclaw] Level 0 (0-3) step   153 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8501
# [fclaw] Level 0 (0-3) step   154 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8556
# [fclaw] Level 0 (0-3) step   155 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8612
# [fclaw] Level 0 (0-3) step   156 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8668
# [fclaw] Level 0 (0-3) step   157 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8723
# [fclaw] Level 0 (0-3) step   158 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8779
# [fclaw] Level 0 (0-3) step   159 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8834
# [fclaw] Level 0 (0-3) step   160 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8890
# [fclaw] Level 0 (0-3) step   161 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.8946
# [fclaw] Level 0 (0-3) step   162 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9001
# [fclaw] Level 0 (0-3) step   163 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9057
# [fclaw] Level 0 (0-3) step   164 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9113
# [fclaw] Level 0 (0-3) step   165 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9168
# [fclaw] Level 0 (0-3) step   166 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9224
# [fclaw] Level 0 (0-3) step   167 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9279
# [fclaw] Level 0 (0-3) step   168 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9335
# [fclaw] Level 0 (0-3) step   169 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9391
# [fclaw] Level 0 (0-3) step   170 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9446
# [fclaw] Level 0 (0-3) step   171 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9502
# [fclaw] Level 0 (0-3) step   172 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9558
# [fclaw] Level 0 (0-3) step   173 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9613
# [fclaw] Level 0 (0-3) step   174 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9669
# [fclaw] Level 0 (0-3) step   175 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9724
# [fclaw] Level 0 (0-3) step   176 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9780
# [fclaw] Level 0 (0-3) step   177 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9836
# [fclaw] Level 0 (0-3) step   178 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9891
# [fclaw] Level 0 (0-3) step   179 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       0.9947
# [fclaw] Level 0 (0-3) step   180 : dt =    5.310e-03; maxcfl (step) =    0.859; Final time =       1.0000
# [fclaw] Output Frame    5  at time   1.00000000e+00
#
# [fclaw] Level 0 (0-3) step   181 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0056
# [fclaw] Level 0 (0-3) step   182 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0111
# [fclaw] Level 0 (0-3) step   183 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0167
# [fclaw] Level 0 (0-3) step   184 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0223
# [fclaw] Level 0 (0-3) step   185 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0278
# [fclaw] Level 0 (0-3) step   186 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0334
# [fclaw] Level 0 (0-3) step   187 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0389
# [fclaw] Level 0 (0-3) step   188 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0445
# [fclaw] Level 0 (0-3) step   189 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0501
# [fclaw] Level 0 (0-3) step   190 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0556
# [fclaw] Level 0 (0-3) step   191 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0612
# [fclaw] Level 0 (0-3) step   192 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0668
# [fclaw] Level 0 (0-3) step   193 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0723
# [fclaw] Level 0 (0-3) step   194 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0779
# [fclaw] Level 0 (0-3) step   195 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0834
# [fclaw] Level 0 (0-3) step   196 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0890
# [fclaw] Level 0 (0-3) step   197 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.0946
# [fclaw] Level 0 (0-3) step   198 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.1001
# [fclaw] Level 0 (0-3) step   199 : dt =    5.563e-03; maxcfl (step) =    0.900; Final time =       1.1057
# [fclaw] Level 0 (0-3) step   200 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1113
# [fclaw] Level 0 (0-3) step   201 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1168
# [fclaw] Level 0 (0-3) step   202 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1224
# [fclaw] Level 0 (0-3) step   203 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1279
# [fclaw] Level 0 (0-3) step   204 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1335
# [fclaw] Level 0 (0-3) step   205 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1391
# [fclaw] Level 0 (0-3) step   206 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1446
# [fclaw] Level 0 (0-3) step   207 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1502
# [fclaw] Level 0 (0-3) step   208 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1557
# [fclaw] Level 0 (0-3) step   209 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1613
# [fclaw] Level 0 (0-3) step   210 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1669
# [fclaw] Level 0 (0-3) step   211 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1724
# [fclaw] Level 0 (0-3) step   212 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1780
# [fclaw] Level 0 (0-3) step   213 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1836
# [fclaw] Level 0 (0-3) step   214 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1891
# [fclaw] Level 0 (0-3) step   215 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.1947
# [fclaw] Level 0 (0-3) step   216 : dt =    5.326e-03; maxcfl (step) =    0.862; Final time =       1.2000
# [fclaw] Output Frame    6  at time   1.20000000e+00
#
# [fclaw] Level 0 (0-3) step   217 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2056
# [fclaw] Level 0 (0-3) step   218 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2111
# [fclaw] Level 0 (0-3) step   219 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2167
# [fclaw] Level 0 (0-3) step   220 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2222
# [fclaw] Level 0 (0-3) step   221 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2278
# [fclaw] Level 0 (0-3) step   222 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2334
# [fclaw] Level 0 (0-3) step   223 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2389
# [fclaw] Level 0 (0-3) step   224 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2445
# [fclaw] Level 0 (0-3) step   225 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2501
# [fclaw] Level 0 (0-3) step   226 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2556
# [fclaw] Level 0 (0-3) step   227 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2612
# [fclaw] Level 0 (0-3) step   228 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2667
# [fclaw] Level 0 (0-3) step   229 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2723
# [fclaw] Level 0 (0-3) step   230 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2779
# [fclaw] Level 0 (0-3) step   231 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2834
# [fclaw] Level 0 (0-3) step   232 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2890
# [fclaw] Level 0 (0-3) step   233 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.2945
# [fclaw] Level 0 (0-3) step   234 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3001
# [fclaw] Level 0 (0-3) step   235 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3057
# [fclaw] Level 0 (0-3) step   236 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3112
# [fclaw] Level 0 (0-3) step   237 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3168
# [fclaw] Level 0 (0-3) step   238 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3224
# [fclaw] Level 0 (0-3) step   239 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3279
# [fclaw] Level 0 (0-3) step   240 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3335
# [fclaw] Level 0 (0-3) step   241 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3390
# [fclaw] Level 0 (0-3) step   242 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3446
# [fclaw] Level 0 (0-3) step   243 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3502
# [fclaw] Level 0 (0-3) step   244 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3557
# [fclaw] Level 0 (0-3) step   245 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3613
# [fclaw] Level 0 (0-3) step   246 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3668
# [fclaw] Level 0 (0-3) step   247 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3724
# [fclaw] Level 0 (0-3) step   248 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3780
# [fclaw] Level 0 (0-3) step   249 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3835
# [fclaw] Level 0 (0-3) step   250 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3891
# [fclaw] Level 0 (0-3) step   251 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.3947
# [fclaw] Level 0 (0-3) step   252 : dt =    5.346e-03; maxcfl (step) =    0.865; Final time =       1.4000
# [fclaw] Output Frame    7  at time   1.40000000e+00
#
# [fclaw] Level 0 (0-3) step   253 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4056
# [fclaw] Level 0 (0-3) step   254 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4111
# [fclaw] Level 0 (0-3) step   255 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4167
# [fclaw] Level 0 (0-3) step   256 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4222
# [fclaw] Level 0 (0-3) step   257 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4278
# [fclaw] Level 0 (0-3) step   258 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4334
# [fclaw] Level 0 (0-3) step   259 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4389
# [fclaw] Level 0 (0-3) step   260 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4445
# [fclaw] Level 0 (0-3) step   261 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4501
# [fclaw] Level 0 (0-3) step   262 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4556
# [fclaw] Level 0 (0-3) step   263 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4612
# [fclaw] Level 0 (0-3) step   264 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4667
# [fclaw] Level 0 (0-3) step   265 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4723
# [fclaw] Level 0 (0-3) step   266 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4779
# [fclaw] Level 0 (0-3) step   267 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4834
# [fclaw] Level 0 (0-3) step   268 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4890
# [fclaw] Level 0 (0-3) step   269 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.4945
# [fclaw] Level 0 (0-3) step   270 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5001
# [fclaw] Level 0 (0-3) step   271 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5057
# [fclaw] Level 0 (0-3) step   272 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5112
# [fclaw] Level 0 (0-3) step   273 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5168
# [fclaw] Level 0 (0-3) step   274 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5224
# [fclaw] Level 0 (0-3) step   275 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5279
# [fclaw] Level 0 (0-3) step   276 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5335
# [fclaw] Level 0 (0-3) step   277 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5390
# [fclaw] Level 0 (0-3) step   278 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5446
# [fclaw] Level 0 (0-3) step   279 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5502
# [fclaw] Level 0 (0-3) step   280 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5557
# [fclaw] Level 0 (0-3) step   281 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5613
# [fclaw] Level 0 (0-3) step   282 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5668
# [fclaw] Level 0 (0-3) step   283 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5724
# [fclaw] Level 0 (0-3) step   284 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5780
# [fclaw] Level 0 (0-3) step   285 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5835
# [fclaw] Level 0 (0-3) step   286 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5891
# [fclaw] Level 0 (0-3) step   287 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.5947
# [fclaw] Level 0 (0-3) step   288 : dt =    5.346e-03; maxcfl (step) =    0.865; Final time =       1.6000
# [fclaw] Output Frame    8  at time   1.60000000e+00
#
# [fclaw] Level 0 (0-3) step   289 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6056
# [fclaw] Level 0 (0-3) step   290 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6111
# [fclaw] Level 0 (0-3) step   291 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6167
# [fclaw] Level 0 (0-3) step   292 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6222
# [fclaw] Level 0 (0-3) step   293 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6278
# [fclaw] Level 0 (0-3) step   294 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6334
# [fclaw] Level 0 (0-3) step   295 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6389
# [fclaw] Level 0 (0-3) step   296 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6445
# [fclaw] Level 0 (0-3) step   297 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6501
# [fclaw] Level 0 (0-3) step   298 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6556
# [fclaw] Level 0 (0-3) step   299 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6612
# [fclaw] Level 0 (0-3) step   300 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6667
# [fclaw] Level 0 (0-3) step   301 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6723
# [fclaw] Level 0 (0-3) step   302 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6779
# [fclaw] Level 0 (0-3) step   303 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6834
# [fclaw] Level 0 (0-3) step   304 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6890
# [fclaw] Level 0 (0-3) step   305 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.6945
# [fclaw] Level 0 (0-3) step   306 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7001
# [fclaw] Level 0 (0-3) step   307 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7057
# [fclaw] Level 0 (0-3) step   308 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7112
# [fclaw] Level 0 (0-3) step   309 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7168
# [fclaw] Level 0 (0-3) step   310 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7224
# [fclaw] Level 0 (0-3) step   311 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7279
# [fclaw] Level 0 (0-3) step   312 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7335
# [fclaw] Level 0 (0-3) step   313 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7390
# [fclaw] Level 0 (0-3) step   314 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7446
# [fclaw] Level 0 (0-3) step   315 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7502
# [fclaw] Level 0 (0-3) step   316 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7557
# [fclaw] Level 0 (0-3) step   317 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7613
# [fclaw] Level 0 (0-3) step   318 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7668
# [fclaw] Level 0 (0-3) step   319 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7724
# [fclaw] Level 0 (0-3) step   320 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7780
# [fclaw] Level 0 (0-3) step   321 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7835
# [fclaw] Level 0 (0-3) step   322 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7891
# [fclaw] Level 0 (0-3) step   323 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.7947
# [fclaw] Level 0 (0-3) step   324 : dt =    5.346e-03; maxcfl (step) =    0.865; Final time =       1.8000
# [fclaw] Output Frame    9  at time   1.80000000e+00
#
# [fclaw] Level 0 (0-3) step   325 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8056
# [fclaw] Level 0 (0-3) step   326 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8111
# [fclaw] Level 0 (0-3) step   327 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8167
# [fclaw] Level 0 (0-3) step   328 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8222
# [fclaw] Level 0 (0-3) step   329 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8278
# [fclaw] Level 0 (0-3) step   330 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8334
# [fclaw] Level 0 (0-3) step   331 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8389
# [fclaw] Level 0 (0-3) step   332 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8445
# [fclaw] Level 0 (0-3) step   333 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8501
# [fclaw] Level 0 (0-3) step   334 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8556
# [fclaw] Level 0 (0-3) step   335 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8612
# [fclaw] Level 0 (0-3) step   336 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8667
# [fclaw] Level 0 (0-3) step   337 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8723
# [fclaw] Level 0 (0-3) step   338 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8779
# [fclaw] Level 0 (0-3) step   339 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8834
# [fclaw] Level 0 (0-3) step   340 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8890
# [fclaw] Level 0 (0-3) step   341 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.8945
# [fclaw] Level 0 (0-3) step   342 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9001
# [fclaw] Level 0 (0-3) step   343 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9057
# [fclaw] Level 0 (0-3) step   344 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9112
# [fclaw] Level 0 (0-3) step   345 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9168
# [fclaw] Level 0 (0-3) step   346 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9224
# [fclaw] Level 0 (0-3) step   347 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9279
# [fclaw] Level 0 (0-3) step   348 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9335
# [fclaw] Level 0 (0-3) step   349 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9390
# [fclaw] Level 0 (0-3) step   350 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9446
# [fclaw] Level 0 (0-3) step   351 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9502
# [fclaw] Level 0 (0-3) step   352 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9557
# [fclaw] Level 0 (0-3) step   353 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9613
# [fclaw] Level 0 (0-3) step   354 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9668
# [fclaw] Level 0 (0-3) step   355 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9724
# [fclaw] Level 0 (0-3) step   356 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9780
# [fclaw] Level 0 (0-3) step   357 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9835
# [fclaw] Level 0 (0-3) step   358 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9891
# [fclaw] Level 0 (0-3) step   359 : dt =    5.562e-03; maxcfl (step) =    0.900; Final time =       1.9947
# [fclaw] Level 0 (0-3) step   360 : dt =    5.346e-03; maxcfl (step) =    0.865; Final time =       2.0000
# [fclaw] Output Frame   10  at time   2.00000000e+00
#
# [fclaw] Finalizing run
# [libsc] Statistics for   WALLTIME
# [libsc]    Global number of values:       1
# [libsc]    Mean value (std. dev.):           654.719 (0 = 0%)
# [libsc]    Minimum attained at rank       0: 654.719
# [libsc]    Maximum attained at rank       0: 654.719
# [libsc] Procs 1 advance 361 627.014 exchange 3213 14.4121 regrid 360 349 4.68919
# [libsc] Max/P 1 advance 361 627.014 exchange 3213 14.4121 regrid 360 349 4.68919

# %% [markdown]
# ## Create gauge handing files
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
#
#
# ForestClaw will read gauge information from a file `gauges.data`, and produce an output gauge file `gauge000<N>.txt` for each gauge.
#
#
# ### Writing input gauge files
#
# This file should be in the following format :
#
# **Line 1:** Number of gauges to read (**N**)
#
#
# **Lines 2-N+1:** Gauge data for each gauge
#
#     <gauge_id>  <x_long>  <y_lat> <t0>  <t1>
#
# where `gauge_id` is an ID number associated with the gauge (need not be consecutive). The location of the gauge $(x_{long}, y_{lat})$ specifies the location of the gauge in longitude and latitude degrees.  The longitude is assumed to be in $[-180,180]$ and the latitude is in $[-90,90]$.  Gauge values will be logged over the time interval $[t_0, t_1]$.
#
# A typical `gauges.data` file looks like :
#
#     3
#         0      -120.50        37.00     0.00e+00     1.00e+10
#         1      -120.00        37.00     0.00e+00     1.00e+10
#         2      -119.50        37.00     0.00e+00     1.00e+10

# %%
def write_gauge_input_file(x_long,y_lat,t0=0,t1=1e10):
    m = len(x_long)
    assert len(y_lat) == m, 'Number of gauge coordinates supplied much match'
    
    f = open('gauges.data','w')
    f.write("{:d}\n".format(m_gauges))
    if isscalar(t0):
        t0v = [t0]*m
        t1v = [t1]*m
    else:
        assert len(t0) == m, 'Number t0 coordinates supplied much match'
        assert len(t1) == m, 'Number t1 coordinates supplied much match'
        t0v = t0
        t1v = t1
    for i in range(m_gauges):
        id = i
        f.write("{:5d} {:12.2f} {:12.2f} {:12.2e} {:12.2e}\n".format(id,p_long[i],p_lat[i],t0v[i],t1v[i]))
    f.close()

# %%
m_gauges = 3

# Define gauges here in long/lat coordinates
p_long = array([-120.5, -120, -119.5],dtype='float')
p_lat = array([37]*m_gauges,dtype='float')

write_gauge_input_file(p_long,p_lat)

# %%
# %%script bash
#
# cat gauges.data

# %% [markdown]
# ### Reading output gauge files
# Write function to read gauge data output.  This file will read temporal data from each gauge and return a vector of values representing values of gauge data at final time.

# %%
from os.path import exists

# Read gauge files and collect data

def read_gauge_output_file():
    gauge_file = "gauge{:05d}.txt".format
    qvar_data = empty((m_gauges,1))

    errout = 0
    for i in range(m_gauges):
        gfile = gauge_file(i)
        if not exists(gfile):
            errout = 1
            return qvar_data,errout
        
        # Data matrix has three columns : (level, t, q)
        data = loadtxt(gfile)        
        
        # Get q value at final time
        qvar_data[i] = data[-1,2]

    return qvar_data,errout

# %% [markdown]
# ## Create data
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# Here we create some data.   This will read the input gauge file created above and create output files `gauge00001.txt`,
# `gauge00002.txt`, ....

# %% [markdown]
# Do one run of the code with a $S_{true}$ value.  Then perturb the data to get our observations.

# %%
errout, output = run_ForestClaw(S_true,alpha_true)
if errout != 0:
    print("Problem running ForestClaw")
    exit(0)
else:
    print("ForestClaw ran successfully.")

# Read gauges files that were created to get "observations"
qdata,errout = read_gauge_output_file()
if errout != 0:
    print("Problem reading gauge files {:s}".format(gfile))
    exit(0)
else:
    print("Read output gauge files successfully.")
    
# TODO : Add a random perturbation to qvar_data vector entries

qvar_observations = qdata # + error

print("Success!")
print(qvar_observations)

# Reset ForestClaw counter
fclaw_counter = 0

# %% [markdown]
# ## Estimate parameters from data
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# Think about linear least squares  to fit data to a polynomial :
#
# \begin{equation}
# f(x)  = ax^2 + bx + c
# \end{equation}
#
# We set up a matrix equation for unknowns $(a,b,c)$, which we can store in a vector $\mathbf p = [a,b,c]^T$.
#
# The linear least squares problem is then to find
#
# \begin{equation}
# \overline{\mathbf p} = \mbox{argmin} \Vert V \mathbf p - \mathbf b \Vert^2
# \end{equation}
#
# where $V$ is a Vandermonde matrix and entries of $\mathbf b$ are values $y_j = f(x_j)$, $j = 1,2,\dots m$.
#
# More generally, we can solve
#
# \begin{equation}
# \overline{\mathbf p} = \mbox{argmin} \Vert \mathbf G(\mathbf p)  - \mathbf d \Vert^2
# \end{equation}
#
# where $\mathbf G(\mathbf p)$ is the vector of values from $m$ gauges for parameter choices in vector $\mathbf p$.

# %%
# Some problem dependent parameters

def G(p):
    S = p[0]
    alpha = p[1]
    print("S = ",S,";  alpha = ",alpha)
    errout = run_ForestClaw(S,alpha)
    if errout[0] != 0:
        print("Problem running ForestClaw")
        exit(0)    
        
    # Read output gauge files generated by ForestClaw
    qdata,errout = read_gauge_output_file()
    if errout != 0:
        print("Problem reading gauge files {:s}".format(gfile))
        exit(0)
        
    return qdata

# Function to being minimized. 
def F(p):    
    
    # If optimizing for S and alpha, p = [S,alpha]
    Gp = G(p)
    Fval = Gp - qvar_observations
    Fval.resize(m_gauges)
    
    return Fval

# %% [markdown]
# ### Define Jacobian
#
# The Jacobian matrix can be computed using a finite difference model.  Here, we have to select differential $\Delta \mathbf p$ for each parameter.

# %%
def Jac_constant(p):
    # Compute Jacobian for source_model 1
    I = eye(nparms)
    hv = array([1, 5e-5])    # Appropriate h values for each variable
    jacm = empty((m_gauges,nparms))
    
    # Set first column
    j = 0
    ej = I[:,j:j+1].reshape((nparms,))
    dp = ej*hv[j]
    fp = F(p + dp)
    fm = F(p - dp)
    fcol = (fp - fm)/(2*hv[j])
    fcol.resize((m_gauges,1))
    jacm[:,j:j+1] = fcol
    
    # Second column is zero for source_model = 1, so we don't need to do anything.
    j = 1
    jacm[:,j:j+1] = zeros((m_gauges,1))
    
    return jacm


def jac(p):
    if source_model == 1:
        # Jacobian is constant
        return J0
    else:
        I = eye(nparms)
        hv = array([1, 5e-5])    # Appropriate h values for each variable
        
        # First column is constant
        jacm = J0

        # set second column of Jacobian (depends on alpha)
        j = 1
        ej = I[:,j:j+1].reshape((nparms,))
        dp = ej*hv[j]
        fp = F(p + dp)
        fm = F(p - dp)
        fcol = (fp - fm)/(2*hv[j])
        fcol.resize((m_gauges,1))
        jacm[:,j:j+1] = fcol
    
    return jacm

# %% [markdown]
# ## Solve least squares problem
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We solve the nonlinear least squares problem using a routine from SciPy.

# %%
from scipy.optimize import least_squares

# Set constant Jacobian (for first column, or source_model = 1)
p0 = array([S_true,alpha_true])
J0 = Jac_constant(p0)
        
x0 = array([15,1.0e-4])
S_soln = least_squares(F,x0,jac = jac, method='lm',gtol=1e-6)
display(S_soln)
xsoln = S_soln.x
print("Solution is ",  S_soln.x)

# %% [markdown]
# ## Display estimated parameters
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We now run ForestClaw one more time with estimated parameters.  This will create output files fort.q*

# %%
from IPython.display import Markdown

S_est = xsoln[0]
sstr = Markdown(r"$S$  (estimated) = ")
#display(sstr,S_est)
print("{:>30s} {:12.4f}".format("S (estimated)",S_est))

alpha_est = xsoln[1]
rstr = Markdown(r"$\alpha$  (estimated) = ")
#display(rstr,alpha_est)
print("{:>30s} {:12.4e}".format("alpha (estimated)",alpha_est))

print("{:>30s} {:12d}".format("Number of ForestClaw calls",fclaw_counter))

# %% [markdown]
# ## Run ForestClaw with estimated parameters
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We run ForestClaw one final time with estimated parameters.  This will also create output files we can use for plotting.

# %%
# Run ForestClaw using estimated parameters
errout,output = run_ForestClaw(S_est,alpha_est)
print(output.stdout)
