# %%
# %matplotlib notebook

from numpy import *
import numpy.linalg 
from numpy.random import rand
from matplotlib.pyplot import *

# %%
import subprocess
import shlex
import os

# %% [markdown]
# This notebook has two parts.
#
# * **Part 1:** Here, we create artificial data to simulate "observations" at gauges at a final output time $T$. These gauges are described to be observation stations where PM 2.5 concentrations are collected. In selecting these gauges, we used the United States Environmental Protection Agency Air Quality Data of 2020, to choose some cities in California that recorded high PM 2.5 trends. The final output time...
#
#
# * **Part 2:** Estimate the value of $S$ by solving a least squares problem.  This will be a linear or nonlinear  problem depending on the source model being solved, that is, a constant step function or Gaussian model, with dimension equal to the the number of gauges.  The function to be optimized involves a call to ForestClaw.
#
# As a first step, we test that we can run ForestClaw from this notebook.

# %% [markdown]
# ### Problem setup
#
# This code assumes that we will only observe solution at final time.

# %%
# This is the command that will get called from the command line
## source_model = 1: constant function
## source_model = 2: gaussian function

source_model = 1  

S_true = 20
alpha_true = 0.0001

# Number of parameters to estimate
nparms = 2

#shell_cmd = './latlong --user:source-model={:d} --user:S0={:.2f} --user:alpha={:.4e}'.format

#!pwd

# Keep track of how many times we call ForestClaw
fclaw_counter = 0

# %% [markdown]
# ## ForestClaw wrapper
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We can wrap ForestClaw in a Python function.
#
# * Reads data from `fclaw_options.ini`, spatial and temporal resolution
#
# * A ForestClaw run will read data from a gauge file (created below) and report on values at gauges at regular time intervals, specified in ForestClaw options file `fclaw_options.ini'
#
# * This wrapper takes two input parameters $S$ and $\alpha$ that control the source term.  The source term model is also used, but is set as a global variable above.
#
# * The output are gauge files, that are read in routines below.  The function $G(S,\alpha)$ will call this function and return the value of $q(x,t)$ at the final time, at each of the gauges.

# %%
def run_ForestClaw(S, alpha):
    # Parameters : 
    global fclaw_counter
    shell_cmd = './latlong --user:source-model={:d} --user:S0={:.16f} --user:alpha={:.16e}'.format
    cmd = shell_cmd(source_model, S, alpha)
    arg_list = shlex.split(cmd) 
    output = subprocess.run(arg_list, capture_output=True,text=True)
    
    fclaw_counter += 1
    return output.returncode, output

# %% [markdown]
# ### Test ForestClaw wrapper

# %%
# Test that we can call ForestClaw

errout,output = run_ForestClaw(S_true,alpha_true)

if errout != 0:
    print("latlong : Something bad happened!")
    print(output.stdout)
    exit(0)
else:
    print("Test successful!")        
    
# Reset counter
fclaw_counter = 0
    
print(output.stdout)
# Out:
# Test successful!
# [libsc] This is libsc 2.8.1.57-a813
# [libsc] CPP                      /opt/local/bin/mpicc -E
# [libsc] CPPFLAGS
# [libsc] CC                       /opt/local/bin/mpicc
# [libsc] CFLAGS
# [libsc] LDFLAGS                  -Wl,-syslibroot,/Library/Developer/CommandLineTools/SDKs/MacOSX11.sdk -Wl,-flat_namespace -Wl,-commons,use_dylibs -L/opt/local/lib
# [libsc] LIBS                     /opt/local/lib/libz.dylib;m
# [p4est] This is p4est 2.0.94-00da
# [p4est] CPP                      /opt/local/bin/mpicc -E
# [p4est] CPPFLAGS
# [p4est] CC                       /opt/local/bin/mpicc
# [p4est] CFLAGS                   -O2 -g -Wall -DP4EST_ENABLE_DEBUG=1 -DSC_ENABLE_DEBUG=1
# [p4est] LDFLAGS
# [p4est] LIBS                     ;/opt/local/lib/libz.dylib;m
# [fclaw] This is ForestClaw 0.1.4880-4dae
# [fclaw] CPP                      /opt/local/bin/mpicc -E
# [fclaw] CPPFLAGS
# [fclaw] F77
# [fclaw] FFLAGS                   -O2 -g -Wall -Wno-unused-dummy-argument
# [fclaw] CC                       /opt/local/bin/mpicc
# [fclaw] CFLAGS                   -O2 -g -Wall -DFCLAW_ENABLE_DEBUG=1
# [fclaw] CXX                      /opt/local/bin/mpicxx
# [fclaw] CXXFLAGS
# [fclaw] LDFLAGS                  -Wl,-syslibroot,/Library/Developer/CommandLineTools/SDKs/MacOSX12.sdk -Wl,-commons,use_dylibs
# [fclaw] FLIBS
# [fclaw] LIBS                     ;/opt/local/lib/libz.dylib;m
# [fclaw] Reading file fclaw_options.ini.
# [fclaw] Options:
# [fclaw]    help                                 false
# [fclaw]    version                              false
# [fclaw]    print-options                        false
# [fclaw]    verbosity                            production
# [fclaw]    lib-verbosity                        essential
# [fclaw]    initial_dt                           0.01
# [fclaw]    max_cfl                              1
# [fclaw]    desired_cfl                          0.9
# [fclaw]    reduce-cfl                           true
# [fclaw]    use_fixed_dt                         false
# [fclaw]    outstyle                             1
# [fclaw]    tfinal                               2
# [fclaw]    nout                                 8
# [fclaw]    nstep                                1
# [fclaw]    advance-one-step                     false
# [fclaw]    outstyle-uses-maxlevel               false
# [fclaw]    subcycle                             true
# [fclaw]    ghost-fill-uses-time-interp          true
# [fclaw]    weighted_partition                   true
# [fclaw]    time-sync                            false
# [fclaw]    flux-correction                      true
# [fclaw]    fluctuation-correction               true
# [fclaw]    output                               true
# [fclaw]    output-gauges                        false
# [fclaw]    gauge-buffer-length                  1
# [fclaw]    tikz-out                             false
# [fclaw]    tikz-figsize                         8 6
# [fclaw]    tikz-plot-prefix                     plot
# [fclaw]    tikz-plot-suffix                     png
# [fclaw]    tikz-mesh-only                       false
# [fclaw]    tikz-plot-fig                        true
# [fclaw]    prefix                               fort
# [fclaw]    vtkspace                             0
# [fclaw]    init_ghostcell                       false
# [fclaw]    minlevel                             0
# [fclaw]    maxlevel                             3
# [fclaw]    regrid_interval                      1
# [fclaw]    refratio                             2
# [fclaw]    smooth-refine                        true
# [fclaw]    smooth-level                         3
# [fclaw]    coarsen-delay                        0
# [fclaw]    refine_threshold                     0.0001
# [fclaw]    coarsen_threshold                    1e-05
# [fclaw]    run-user-diagnostics                 false
# [fclaw]    compute-error                        false
# [fclaw]    conservation-check                   false
# [fclaw]    report-timing                        true
# [fclaw]    report-timing-verbosity              wall
# [fclaw]    ghost-patch-pack-area                false
# [fclaw]    ghost-patch-pack-extra               false
# [fclaw]    ghost-patch-pack-numextrafields      0
# [fclaw]    trapfpe                              false
# [fclaw]    mpi_debug                            false
# [fclaw]    ax                                   0
# [fclaw]    bx                                   1
# [fclaw]    ay                                   0
# [fclaw]    by                                   1
# [fclaw]    az                                   0
# [fclaw]    bz                                   1
# [fclaw]    manifold                             true
# [fclaw]    mi                                   5
# [fclaw]    mj                                   6
# [fclaw]    periodic_x                           false
# [fclaw]    periodic_y                           false
# [fclaw]    scale                                1 1 1
# [fclaw]    shift                                0 0 0
# [fclaw]    phi                                  0
# [fclaw]    theta                                0
# [fclaw]    clawpatch:mx                         16
# [fclaw]    clawpatch:my                         16
# [fclaw]    clawpatch:maux                       7
# [fclaw]    clawpatch:mbc                        2
# [fclaw]    clawpatch:meqn                       1
# [fclaw]    clawpatch:rhs-fields                 1
# [fclaw]    clawpatch:interp_stencil_width       3
# [fclaw]    clawpatch:ghost_patch_pack_aux       false
# [fclaw]    clawpatch:save-aux                   false
# [fclaw]    clawpatch:refinement-criteria        value
# [fclaw]    clawpack46:order                     2 2
# [fclaw]    clawpack46:mcapa                     1
# [fclaw]    clawpack46:src_term                  true
# [fclaw]    clawpack46:use-fwaves                true
# [fclaw]    clawpack46:mwaves                    1
# [fclaw]    clawpack46:mthlim                    3
# [fclaw]    clawpack46:mthbc                     1 1 1 1
# [fclaw]    clawpack46:ascii-out                 true
# [fclaw]    clawpack46:vtk-out                   false
# [fclaw]    user:example                         1
# [fclaw]    user:initial-condition               0
# [fclaw]    user:source-model                    1
# [fclaw]    user:radius-fire                     1.5
# [fclaw]    user:radius-sphere                   1
# [fclaw]    user:S0                              20
# [fclaw]    user:alpha                           0.0001
# [fclaw]    user:latitude                        32 51
# [fclaw]    user:longitude                       -125 -105
# [fclaw]    user:center-fire                     -120 35.5
# [fclaw]    user:velocity                        0.2 0.2
# [fclaw]    user:claw-version                    4
# [fclaw]    user:example                         1
# [fclaw]    user:initial-condition               0
# [fclaw]    user:source-model                    2
# [fclaw]    user:radius-fire                     1.5
# [fclaw]    user:radius-sphere                   1
# [fclaw]    user:S0                              20
# [fclaw]    user:alpha                           0.0001
# [fclaw]    user:latitude                        32 51
# [fclaw]    user:longitude                       -125 -105
# [fclaw]    user:center-fire                     -120 35.5
# [fclaw]    user:velocity                        0.2 0.2
# [fclaw]    user:claw-version                    4
# [fclaw] Arguments: none
# [p4est 0] Local minimum/maximum levels:  0  0
# [p4est] Global minimum/maximum levels:  0  0
# [p4est 0] Patches on level  0:        30
# [fclaw] Max threads set to 0
# [fclaw] Output Frame    0  at time   0.00000000e+00
#
# [fclaw] Level 0 (0-0) step     1 : dt =    1.000e-02; maxcfl (step) =    0.808; Final time =       0.0100
# [fclaw] Level 0 (0-1) step     2 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0211
# [fclaw] Level 0 (0-2) step     3 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0323
# [fclaw] Level 0 (0-3) step     4 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0434
# [fclaw] Level 0 (0-3) step     5 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0545
# [fclaw] Level 0 (0-3) step     6 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0657
# [fclaw] Level 0 (0-3) step     7 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0768
# [fclaw] Level 0 (0-3) step     8 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0879
# [fclaw] Level 0 (0-3) step     9 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.0991
# [fclaw] Level 0 (0-3) step    10 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1102
# [fclaw] Level 0 (0-3) step    11 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1213
# [fclaw] Level 0 (0-3) step    12 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1325
# [fclaw] Level 0 (0-3) step    13 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1436
# [fclaw] Level 0 (0-3) step    14 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1547
# [fclaw] Level 0 (0-3) step    15 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1659
# [fclaw] Level 0 (0-3) step    16 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1770
# [fclaw] Level 0 (0-3) step    17 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1881
# [fclaw] Level 0 (0-3) step    18 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.1993
# [fclaw] Level 0 (0-3) step    19 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2104
# [fclaw] Level 0 (0-3) step    20 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2216
# [fclaw] Level 0 (0-3) step    21 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2327
# [fclaw] Level 0 (0-3) step    22 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2438
# [fclaw] Level 0 (0-3) step    23 : dt =    6.179e-03; maxcfl (step) =    0.499; Final time =       0.2500
# [fclaw] Output Frame    1  at time   2.50000000e-01
#
# [fclaw] Level 0 (0-3) step    24 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2611
# [fclaw] Level 0 (0-3) step    25 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2723
# [fclaw] Level 0 (0-3) step    26 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2834
# [fclaw] Level 0 (0-3) step    27 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.2945
# [fclaw] Level 0 (0-3) step    28 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3057
# [fclaw] Level 0 (0-3) step    29 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3168
# [fclaw] Level 0 (0-3) step    30 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3279
# [fclaw] Level 0 (0-3) step    31 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3391
# [fclaw] Level 0 (0-3) step    32 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3502
# [fclaw] Level 0 (0-3) step    33 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3613
# [fclaw] Level 0 (0-3) step    34 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3725
# [fclaw] Level 0 (0-3) step    35 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3836
# [fclaw] Level 0 (0-3) step    36 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.3947
# [fclaw] Level 0 (0-3) step    37 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4059
# [fclaw] Level 0 (0-3) step    38 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4170
# [fclaw] Level 0 (0-3) step    39 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4281
# [fclaw] Level 0 (0-3) step    40 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4393
# [fclaw] Level 0 (0-3) step    41 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4504
# [fclaw] Level 0 (0-3) step    42 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4616
# [fclaw] Level 0 (0-3) step    43 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4727
# [fclaw] Level 0 (0-3) step    44 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4838
# [fclaw] Level 0 (0-3) step    45 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.4950
# [fclaw] Level 0 (0-3) step    46 : dt =    5.044e-03; maxcfl (step) =    0.408; Final time =       0.5000
# [fclaw] Output Frame    2  at time   5.00000000e-01
#
# [fclaw] Level 0 (0-3) step    47 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5111
# [fclaw] Level 0 (0-3) step    48 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5223
# [fclaw] Level 0 (0-3) step    49 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5334
# [fclaw] Level 0 (0-3) step    50 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5445
# [fclaw] Level 0 (0-3) step    51 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5557
# [fclaw] Level 0 (0-3) step    52 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5668
# [fclaw] Level 0 (0-3) step    53 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5779
# [fclaw] Level 0 (0-3) step    54 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.5891
# [fclaw] Level 0 (0-3) step    55 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6002
# [fclaw] Level 0 (0-3) step    56 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6113
# [fclaw] Level 0 (0-3) step    57 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6225
# [fclaw] Level 0 (0-3) step    58 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6336
# [fclaw] Level 0 (0-3) step    59 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6447
# [fclaw] Level 0 (0-3) step    60 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6559
# [fclaw] Level 0 (0-3) step    61 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6670
# [fclaw] Level 0 (0-3) step    62 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6781
# [fclaw] Level 0 (0-3) step    63 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.6893
# [fclaw] Level 0 (0-3) step    64 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7004
# [fclaw] Level 0 (0-3) step    65 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7116
# [fclaw] Level 0 (0-3) step    66 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7227
# [fclaw] Level 0 (0-3) step    67 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7338
# [fclaw] Level 0 (0-3) step    68 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7450
# [fclaw] Level 0 (0-3) step    69 : dt =    5.044e-03; maxcfl (step) =    0.408; Final time =       0.7500
# [fclaw] Output Frame    3  at time   7.50000000e-01
#
# [fclaw] Level 0 (0-3) step    70 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7611
# [fclaw] Level 0 (0-3) step    71 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7723
# [fclaw] Level 0 (0-3) step    72 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7834
# [fclaw] Level 0 (0-3) step    73 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.7945
# [fclaw] Level 0 (0-3) step    74 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8057
# [fclaw] Level 0 (0-3) step    75 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8168
# [fclaw] Level 0 (0-3) step    76 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8279
# [fclaw] Level 0 (0-3) step    77 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8391
# [fclaw] Level 0 (0-3) step    78 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8502
# [fclaw] Level 0 (0-3) step    79 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8613
# [fclaw] Level 0 (0-3) step    80 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8725
# [fclaw] Level 0 (0-3) step    81 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8836
# [fclaw] Level 0 (0-3) step    82 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.8947
# [fclaw] Level 0 (0-3) step    83 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9059
# [fclaw] Level 0 (0-3) step    84 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9170
# [fclaw] Level 0 (0-3) step    85 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9281
# [fclaw] Level 0 (0-3) step    86 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9393
# [fclaw] Level 0 (0-3) step    87 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9504
# [fclaw] Level 0 (0-3) step    88 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9616
# [fclaw] Level 0 (0-3) step    89 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9727
# [fclaw] Level 0 (0-3) step    90 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9838
# [fclaw] Level 0 (0-3) step    91 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       0.9950
# [fclaw] Level 0 (0-3) step    92 : dt =    5.044e-03; maxcfl (step) =    0.408; Final time =       1.0000
# [fclaw] Output Frame    4  at time   1.00000000e+00
#
# [fclaw] Level 0 (0-3) step    93 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0111
# [fclaw] Level 0 (0-3) step    94 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0223
# [fclaw] Level 0 (0-3) step    95 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0334
# [fclaw] Level 0 (0-3) step    96 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0445
# [fclaw] Level 0 (0-3) step    97 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0557
# [fclaw] Level 0 (0-3) step    98 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0668
# [fclaw] Level 0 (0-3) step    99 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.0779
# [fclaw] Level 0 (0-3) step   100 : dt =    1.113e-02; maxcfl (step) =    0.901; Final time =       1.0891
# [fclaw] Level 0 (0-3) step   101 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1002
# [fclaw] Level 0 (0-3) step   102 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1113
# [fclaw] Level 0 (0-3) step   103 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1225
# [fclaw] Level 0 (0-3) step   104 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1336
# [fclaw] Level 0 (0-3) step   105 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1447
# [fclaw] Level 0 (0-3) step   106 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1558
# [fclaw] Level 0 (0-3) step   107 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1670
# [fclaw] Level 0 (0-3) step   108 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1781
# [fclaw] Level 0 (0-3) step   109 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.1892
# [fclaw] Level 0 (0-3) step   110 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2003
# [fclaw] Level 0 (0-3) step   111 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2115
# [fclaw] Level 0 (0-3) step   112 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2226
# [fclaw] Level 0 (0-3) step   113 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2337
# [fclaw] Level 0 (0-3) step   114 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2448
# [fclaw] Level 0 (0-3) step   115 : dt =    5.173e-03; maxcfl (step) =    0.419; Final time =       1.2500
# [fclaw] Output Frame    5  at time   1.25000000e+00
#
# [fclaw] Level 0 (0-3) step   116 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2611
# [fclaw] Level 0 (0-3) step   117 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2723
# [fclaw] Level 0 (0-3) step   118 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2834
# [fclaw] Level 0 (0-3) step   119 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.2945
# [fclaw] Level 0 (0-3) step   120 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3056
# [fclaw] Level 0 (0-3) step   121 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3168
# [fclaw] Level 0 (0-3) step   122 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3279
# [fclaw] Level 0 (0-3) step   123 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3390
# [fclaw] Level 0 (0-3) step   124 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3501
# [fclaw] Level 0 (0-3) step   125 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3613
# [fclaw] Level 0 (0-3) step   126 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3724
# [fclaw] Level 0 (0-3) step   127 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3835
# [fclaw] Level 0 (0-3) step   128 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.3946
# [fclaw] Level 0 (0-3) step   129 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4058
# [fclaw] Level 0 (0-3) step   130 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4169
# [fclaw] Level 0 (0-3) step   131 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4280
# [fclaw] Level 0 (0-3) step   132 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4391
# [fclaw] Level 0 (0-3) step   133 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4503
# [fclaw] Level 0 (0-3) step   134 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4614
# [fclaw] Level 0 (0-3) step   135 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4725
# [fclaw] Level 0 (0-3) step   136 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4836
# [fclaw] Level 0 (0-3) step   137 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.4948
# [fclaw] Level 0 (0-3) step   138 : dt =    5.247e-03; maxcfl (step) =    0.424; Final time =       1.5000
# [fclaw] Output Frame    6  at time   1.50000000e+00
#
# [fclaw] Level 0 (0-3) step   139 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5111
# [fclaw] Level 0 (0-3) step   140 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5223
# [fclaw] Level 0 (0-3) step   141 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5334
# [fclaw] Level 0 (0-3) step   142 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5445
# [fclaw] Level 0 (0-3) step   143 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5556
# [fclaw] Level 0 (0-3) step   144 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5668
# [fclaw] Level 0 (0-3) step   145 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5779
# [fclaw] Level 0 (0-3) step   146 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.5890
# [fclaw] Level 0 (0-3) step   147 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6001
# [fclaw] Level 0 (0-3) step   148 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6113
# [fclaw] Level 0 (0-3) step   149 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6224
# [fclaw] Level 0 (0-3) step   150 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6335
# [fclaw] Level 0 (0-3) step   151 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6446
# [fclaw] Level 0 (0-3) step   152 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6558
# [fclaw] Level 0 (0-3) step   153 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6669
# [fclaw] Level 0 (0-3) step   154 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6780
# [fclaw] Level 0 (0-3) step   155 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.6891
# [fclaw] Level 0 (0-3) step   156 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7003
# [fclaw] Level 0 (0-3) step   157 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7114
# [fclaw] Level 0 (0-3) step   158 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7225
# [fclaw] Level 0 (0-3) step   159 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7336
# [fclaw] Level 0 (0-3) step   160 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7448
# [fclaw] Level 0 (0-3) step   161 : dt =    5.247e-03; maxcfl (step) =    0.424; Final time =       1.7500
# [fclaw] Output Frame    7  at time   1.75000000e+00
#
# [fclaw] Level 0 (0-3) step   162 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7611
# [fclaw] Level 0 (0-3) step   163 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7723
# [fclaw] Level 0 (0-3) step   164 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7834
# [fclaw] Level 0 (0-3) step   165 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.7945
# [fclaw] Level 0 (0-3) step   166 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8056
# [fclaw] Level 0 (0-3) step   167 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8168
# [fclaw] Level 0 (0-3) step   168 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8279
# [fclaw] Level 0 (0-3) step   169 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8390
# [fclaw] Level 0 (0-3) step   170 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8501
# [fclaw] Level 0 (0-3) step   171 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8613
# [fclaw] Level 0 (0-3) step   172 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8724
# [fclaw] Level 0 (0-3) step   173 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8835
# [fclaw] Level 0 (0-3) step   174 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.8946
# [fclaw] Level 0 (0-3) step   175 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9058
# [fclaw] Level 0 (0-3) step   176 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9169
# [fclaw] Level 0 (0-3) step   177 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9280
# [fclaw] Level 0 (0-3) step   178 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9391
# [fclaw] Level 0 (0-3) step   179 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9503
# [fclaw] Level 0 (0-3) step   180 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9614
# [fclaw] Level 0 (0-3) step   181 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9725
# [fclaw] Level 0 (0-3) step   182 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9836
# [fclaw] Level 0 (0-3) step   183 : dt =    1.113e-02; maxcfl (step) =    0.900; Final time =       1.9948
# [fclaw] Level 0 (0-3) step   184 : dt =    5.247e-03; maxcfl (step) =    0.424; Final time =       2.0000
# [fclaw] Output Frame    8  at time   2.00000000e+00
#
# [fclaw] Finalizing run
# [libsc] Statistics for   WALLTIME
# [libsc]    Global number of values:       1
# [libsc]    Mean value (std. dev.):           110.796 (0 = 0%)
# [libsc]    Minimum attained at rank       0: 110.796
# [libsc]    Maximum attained at rank       0: 110.796
# [libsc] Procs 1 advance 184 89.5045 exchange 1637 15.4015 regrid 184 182 3.79592
# [libsc] Max/P 1 advance 184 89.5045 exchange 1637 15.4015 regrid 184 182 3.79592

# %% [markdown]
# ## Create gauge handing files
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
#
#
# ForestClaw will read gauge information from a file `gauges.data`, and produce an output gauge file `gauge000<N>.txt` for each gauge.
#
#
# ### Writing input gauge files
#
# This file should be in the following format :
#
# **Line 1:** Number of gauges to read (**N**)
#
#
# **Lines 2-N+1:** Gauge data for each gauge
#
#     <gauge_id>  <x_long>  <y_lat> <t0>  <t1>
#
# where `gauge_id` is an ID number associated with the gauge (need not be consecutive). The location of the gauge $(x_{long}, y_{lat})$ specifies the location of the gauge in longitude and latitude degrees.  The longitude is assumed to be in $[-180,180]$ and the latitude is in $[-90,90]$.  Gauge values will be logged over the time interval $[t_0, t_1]$.
#
# A typical `gauges.data` file looks like :
#
#     3
#         0      -120.50        37.00     0.00e+00     1.00e+10
#         1      -120.00        37.00     0.00e+00     1.00e+10
#         2      -119.50        37.00     0.00e+00     1.00e+10

# %%
def write_gauge_input_file(x_long,y_lat,t0=0,t1=1e10):
    m = len(x_long)
    assert len(y_lat) == m, 'Number of gauge coordinates supplied must match'
    
    f = open('gauges.data','w')
    f.write("{:d}\n".format(m_gauges))
    if isscalar(t0):
        t0v = [t0]*m
        t1v = [t1]*m
    else:
        assert len(t0) == m, 'Number t0 coordinates supplied must match'
        assert len(t1) == m, 'Number t1 coordinates supplied must match'
        t0v = t0
        t1v = t1
    for i in range(m_gauges):
        id = i
        f.write("{:5d} {:12.3f} {:12.3f} {:12.2e} {:12.2e}\n".format(id,p_long[i],p_lat[i],t0v[i],t1v[i]))
    f.close()

# %%
m_gauges = 9

# Define gauges here in long/lat coordinates

p_long = array([-119.0187, -119.8947, -120.625, -120.156, -119.375, -120.156, -119.667, -119.375, -120.1088],dtype='float')
p_lat = array([35.3210, 36.1389, 35.125, 34.5, 35.5938, 35.4375, 34.9429, 35.2812, 34.9681],dtype='float')

write_gauge_input_file(p_long,p_lat)

# %%
# %%script bash
#
# cat gauges.data

# %% [markdown]
# ### Reading output gauge files
# Write function to read gauge data output.  This file will read temporal data from each gauge and return a vector of values representing values of gauge data at final time.

# %%
from os.path import exists

# Read gauge files and collect data

def read_gauge_output_file():
    gauge_file = "gauge{:05d}.txt".format
    qvar_data = empty((m_gauges,1))

    errout = 0
    for i in range(m_gauges):
        gfile = gauge_file(i)
        if not exists(gfile):
            errout = 1
            return qvar_data,errout
        
        # Data matrix has three columns : (level, t, q)
        data = loadtxt(gfile)        
        
        # Get q value at final time
        qvar_data[i] = data[-1,2]

    return qvar_data,errout

# %% [markdown]
# ## Create data
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# Here we create some data.   This will read the input gauge file created above and create output files `gauge00001.txt`,
# `gauge00002.txt`, ....

# %% [markdown]
# Do one run of the code with a $S_{true}$ value.  Then perturb the data to get our observations.

# %%
errout, output = run_ForestClaw(S_true,alpha_true)
if errout != 0:
    print("Problem running ForestClaw")
    exit(0)
else:
    print("ForestClaw ran successfully.")

# Read gauges files that were created to get "observations"
qdata,errout = read_gauge_output_file()
if errout != 0:
    print("Problem reading gauge files {:s}".format(gfile))
    exit(0)
else:
    print("Read output gauge files successfully.")
    
# TODO : Add a random perturbation to qvar_data vector entries

qvar_observations = qdata + 0.015 *rand(9,1)# + error

print("Success!")
print(qvar_observations)

# Reset ForestClaw counter
fclaw_counter = 0

# %% [markdown]
# ## Estimate parameters from data
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# The least squares problem is then to find
#
# \begin{equation}
# \overline{\mathbf p} = \mbox{argmin} \Vert \mathbf G(\mathbf p)  - \mathbf d \Vert^2
# \end{equation}
#
# where $\mathbf G(\mathbf p)$ is the vector of values from $m$ gauges for parameter choices in vector $\mathbf p$.

# %%
# Some problem dependent parameters

def G(p):
    S = p[0]
    alpha = p[1]
    print("S = ",S,";  alpha = ",alpha) #remember to comment this so it doesn't print all the time
    errout = run_ForestClaw(S,alpha)
    if errout[0] != 0:
        print("Problem running ForestClaw")
        exit(0)    
        
    # Read output gauge files generated by ForestClaw
    qdata,errout = read_gauge_output_file()
    if errout != 0:
        print("Problem reading gauge files {:s}".format(gfile))
        exit(0)
        
    return qdata

# Function to be minimized. 
def F(p):    
    
    # If optimizing for S and alpha, p = [S,alpha]
    Gp = G(p)
    Fval = Gp - qvar_observations
    Fval.resize(m_gauges)
    
    return Fval

# %% [markdown]
# ### Define Jacobian
#
# The Jacobian matrix can be computed using the first-order central difference approximation.  Here, we have to select differential $\Delta \mathbf p$ for each parameter.

# %%
def Jac_constant(p):
    # Compute Jacobian for source_model 1
    I = eye(nparms)
    hv = array([1, 5e-5])    # Appropriate h values for each variable
    jacm = empty((m_gauges,nparms))
    
    # Set first column
    j = 0
    ej = I[:,j:j+1].reshape((nparms,))
    dp = ej*hv[j]
    fp = F(p + dp)
    fm = F(p - dp)
    fcol = (fp - fm)/(2*hv[j])
    fcol.resize((m_gauges,1))
    jacm[:,j:j+1] = fcol
    
    # Second column is zero for source_model = 1, so we don't need to do anything.
    j = 1
    jacm[:,j:j+1] = zeros((m_gauges,1))
    
    return jacm


def jac(p):
    if source_model == 1:
        # Jacobian is constant
        return J0
    else:
        I = eye(nparms)
        hv = array([1, 5e-5])    # Appropriate h values for each variable
        
        # First column is constant
        jacm = J0

        # set second column of Jacobian (depends on alpha)
        j = 1
        ej = I[:,j:j+1].reshape((nparms,))
        dp = ej*hv[j]
        fp = F(p + dp)
        fm = F(p - dp)
        fcol = (fp - fm)/(2*hv[j])
        fcol.resize((m_gauges,1))
        jacm[:,j:j+1] = fcol
    
    return jacm

# %% [markdown]
# ## Solve least squares problem
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We solve the nonlinear least squares problem using a routine from SciPy.

# %%
from scipy.optimize import least_squares

# Set constant Jacobian (for first column, or source_model = 1)
p0 = array([S_true,alpha_true])
J0 = Jac_constant(p0)
        
x0 = array([15,1e-4])
S_soln = least_squares(F,x0,jac = jac, method='lm',gtol=1e-6)
display(S_soln)
xsoln = S_soln.x
print("Solution is ",  S_soln.x)

# %% [markdown]
# ## Display estimated parameters
#
# <hr style="border-width:4px; border-color:coral"></hr>
#
# We now run ForestClaw one more time with estimated parameters.  This will create output files fort.q*

# %%
from IPython.display import Markdown

S_est = xsoln[0]
sstr = Markdown(r"$S$  (estimated) = ")
#display(sstr,S_est)
print("{:>30s} {:12.4f}".format("S (estimated)",S_est))

alpha_est = xsoln[1]
rstr = Markdown(r"$\alpha$  (estimated) = ")
#display(rstr,alpha_est)
print("{:>30s} {:12.4e}".format("alpha (estimated)",alpha_est))

print("{:>30s} {:12d}".format("Number of ForestClaw calls",fclaw_counter))

# %%
# Create output files fort.*

resid = F(xsoln)
print("residual = \n",resid)

# %%
q_estimates = G(xsoln)
print("q_estimates = ")
print("")
print(q_estimates)

# %%
figure(1)
clf

x = arange(1,10)
plot(x, qvar_observations, 'r*', label='obs')
plot(x, q_estimates, 'b*', label='est')
legend()
xlabel("Gauge")
ylabel("q($\mu gm^{-3}$)")
title("PM 2.5 Concentration")
show()

# %%
figure(2)
clf
plot(x, resid, 'r*')
xlabel("Gauge")
ylabel("Residual")
title("Residuals")
show()

# %%
l2_norm = linalg.norm(resid,2)
print("L2_norm = {:6e}".format(l2_norm))

# %%
# Run ForestClaw using estimated parameters
errout,output = run_ForestClaw(S_est,alpha_est)
print(output.stdout)

# %%
print(qvar_observations)

# %%
print(q_estimates)

# %%
# for i in range(0,len(S_true)):


#     errout,output = run_ForestClaw(S_true[i])

#     if errout != 0:
#         print("latlong : Something bad happened!")
#         print(output.stdout)
#         exit(0)
#     else:
#         print("Test successful!")        
    
# # Reset counter
#     fclaw_counter = 0
    
#     print(output.stdout)
